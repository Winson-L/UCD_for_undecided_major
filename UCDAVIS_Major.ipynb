# %%
import json
from bs4 import BeautifulSoup
import requests
import os,csv
import socket
import re
import pandas as pd

# %%
import urllib3
# ?urllib

# %%
url = 'https://ucdavis.pubs.curricunet.com/Catalog/departments-programs-degrees'
text = requests.get(url).text
soup = BeautifulSoup(text,'lxml')

# %%
major_link = soup.find_all('div', attrs={'id': ['bodytop']})
#print(major_link)
# major_link = str(major_link)
# print(major_link)
all_seed = [item['href']
            for i in major_link
            for item in i.find_all('a')
            if 'href' in item.attrs]
majorlist_link = []
for links in all_seed:
    if len(links) > 9:# and 'raduate' not in links:
        majorlist_link.append(links)
print(len(majorlist_link))
# Out:
# 268

# %%
all_seed_name = [item
                for i in major_link
                for item in i.find_all('span')
                if 'class' in item.attrs]
all_seed_name = (list(all_seed_name))

# %%
New_all_seed_name = []
for name in all_seed_name:
    name = str(name)
    name = '1'+ name[1:-1]+'1'
    front_sign = 0
    back_sign = 0
    for sign in name:
        if sign == '>':
            front_sign = name.index(sign)
        elif sign == '<':
            back_sign = name.index(sign)
        else:
            pass
    New_all_seed_name.append(name[front_sign + 1:back_sign])

# %%
New_all_major_name = []
for names in New_all_seed_name:
    #if not 'raduate' in names:
    if True:
        New_all_major_name.append(names)
print(len(New_all_major_name))
# Out:
# 268

# %%
first_final_dict = {}
second_final_dict = {}
third_final_dict = {}
for i in range(len(majorlist_link)):
        first_final_dict.update({majorlist_link[i]:New_all_major_name[i]})
        
for key in first_final_dict.keys():    
    if not 'raduate' in key:
        second_final_dict.update({key:first_final_dict[key]})
for val in second_final_dict.keys():
    if not 'raduate' in second_final_dict[val]:
        third_final_dict.update({val:second_final_dict[val]})
#print(third_final_dict)

# %%
def output_of_major(keylist):
    #url = 'https://ucdavis.pubs.curricunet.com/Catalog/computer-science'
    url = 'https://ucdavis.pubs.curricunet.com' + keylist
    text = requests.get(url).text
    soup = BeautifulSoup(text, 'lxml')
    result = soup.find_all('div', attrs={'class': ['tab-pane active'], 'class': ['container-fluid']})
    result = str(result)

    i = 1
    left_side = []
    right_side = []

    for i in range(len(result)):
        if result[i] == '>' and result[i + 1] != '<':
            left_side.append(i)
        if result[i] == '<' and result[i - 1] != '>':
            right_side.append(i)
        # print(left_side)
        # print('\n'*3)
    try:
        del right_side[right_side.index(1)]
        # print(right_side)
    except:
        pass
    dict1 = {}
    dict = {}
    for each_sign in range(len(right_side)):
        dict.update({left_side[each_sign]: right_side[each_sign]})
    # print(dict)
    for x, y in dict1.items():
        if not (x + 1) == y:
            dict.update({x: y})
    # print(dict)

    merg_list = []
    for x in dict.keys():
        merg_list.append(result[x + 1:dict[x]])

    course = []
    for ListLen in merg_list:
        if len(ListLen) == 3:
            begin_num = merg_list.index(ListLen)
            merg_list = merg_list[begin_num:]
            break

    for ListLen in merg_list:
        if 3 <= len(ListLen) <= 4:
            course.append(ListLen)
    # elif '(' in ListLen or '-' in ListLen:
    #    pass
    course_fix = []
    course_fix_bad = []
    k = 0
    for i in course:
        # print(i)
        if len(re.findall('-', i)) != 0:
            k = 1
            # print(i)
            course_fix_bad.append(i)
        if len(re.findall('\(', i)) != 0:
            k = 1
            course_fix_bad.append(i)
    # print(course_fix_bad)
    for i in course:
        if not i in course_fix_bad:
            course_fix.append(i)
    #print(course_fix)   

    New_course = ['']
    for i in course_fix:
        if (i[0]).isalpha():
            New_course.append(i)
        if (i[0]).isdigit():
            New_course[-1] += i
    del New_course[0]
    # print(New_course)
    New_course1 = []
    for i in New_course:
        if 5 <= len(i) <= 7:
            # del i
            New_course1.append(i)
    # print(New_course)
    sorted(New_course1)
    course_set = ([])
    course_set = set(New_course1)
    #print(course_set)
    return sorted(course_set)

# %%
import time
start = time.time()

first_final_course_dict = {}
i = 0
for result in third_final_dict.keys():
    #print(output_of_major(result))
    if len(output_of_major(result)) >= 0:
        #print(result)
        first_final_course_dict.update({result:output_of_major(result)})
#print(first_final_course_dict)
end = time.time()
print(end - start)
# Out:
# 836.5022010803223

# %%
print(first_final_course_dict)
# Out:
# {'/Catalog/eae': ['CHE002A', 'CHE002B', 'CMN001', 'CMN003', 'COM001', 'COM002', 'COM003', 'COM004', 'EAE001', 'EAE010', 'EAE099', 'EAE126', 'EAE127', 'EAE129', 'EAE130A', 'EAE130B', 'EAE133', 'EAE135', 'EAE137', 'EAE138', 'EAE140', 'EAE141', 'EAE142', 'EAE189C', 'EAE198', 'EAE199', 'EME005', 'EME106', 'EME108', 'EME109', 'EME115', 'EME139', 'EME165', 'EME172', 'ENG003', 'ENG004', 'ENG006', 'ENG017', 'ENG035', 'ENG045', 'ENG045Y', 'ENG100', 'ENG102', 'ENG103', 'ENG104', 'ENG105', 'ENG180', 'ENG190', 'ENL003', 'MAT021A', 'MAT021B', 'MAT021C', 'MAT021D', 'MAT022A', 'MAT022B', 'MAT128C', 'NAS005', 'PHY009A', 'PHY009B', 'PHY009C', 'UWP001', 'UWP001V', 'UWP101', 'UWP102E', 'UWP104A', 'UWP104E', 'UWP104T'], '/Catalog/aas': ['AAS010', 'AAS012', 'AAS015', 'AAS016', 'AAS017', 'AAS018', 'AAS050', 'AAS051', 'AAS052', 'AAS080', 'AAS099', 'AAS100', 'AAS101', 'AAS107A', 'AAS107B', 'AAS107C', 'AAS107D', 'AAS110', 'AAS111', 'AAS123', 'AAS130', 'AAS133', 'AAS141', 'AAS145A', 'AAS145B', 'AAS150A', 'AAS150B', 'AAS151', 'AAS152', 'AAS153', 'AAS155A', 'AAS156', 'AAS157', 'AAS160', 'AAS162', 'AAS163', 'AAS165', 'AAS168', 'AAS169', 'AAS170', 'AAS171', 'AAS172', 'AAS175A', 'AAS175B', 'AAS176', 'AAS177', 'AAS178', 'AAS180', 'AAS181', 'AAS182', 'AAS185', 'AAS190', 'AAS192', 'AAS197T', 'AAS198', 'AAS199', 'AAS201', 'AAS202', 'AAS203', 'AAS204', 'AAS298A', 'AAS298B', 'AAS299', 'AHI150', 'AMS010', 'AMS156', 'ANT002', 'ANT104N', 'ANT140A', 'ANT140B', 'ASA001', 'ASA002', 'CHI010', 'COM154', 'COM165', 'CRD151', 'CRD152', 'CRD172', 'DRA041A', 'DRA041B', 'DRA044A', 'DRA044B', 'DRA155A', 'ECN001A', 'ECN001B', 'ENL167', 'ENL178', 'ENL179', 'ENL181A', 'ENL181B', 'HIS015A', 'HIS015B', 'HIS017A', 'HIS017B', 'HIS102O', 'HIS115A', 'HIS115B', 'HIS115C', 'HIS115D', 'HIS116', 'HIS177A', 'HIS177B', 'HIS178B', 'MUS028', 'MUS105', 'MUS106', 'NAS001', 'NAS010', 'POL001', 'POL002', 'POL134', 'POL176', 'PSC001', 'SOC001', 'SOC128', 'SOC129', 'SOC130', 'SOC134', 'SOC137', 'SOC143A', 'SOC145A', 'SOC145B', 'WMS050', 'WMS160', 'WMS178C', 'WMS180', 'WMS182'], '/Catalog/aging-adult-development': ['EXB117', 'HDE100C', 'HDE110', 'HDE117', 'HDE143', 'HDE160', 'HDE161', 'HDE163', 'PSC121', 'PSC123', 'PSC126', 'PSC130'], '/Catalog/aed': ['ABI102', 'ABT016', 'ABT049', 'ABT052', 'ABT101', 'ABT121', 'ABT142', 'ABT161', 'ABT165', 'ABT182', 'AED092', 'AED098', 'AED099', 'AED100', 'AED160', 'AED171', 'AED172', 'AED190', 'AED192', 'AED198', 'AED199', 'AED300', 'AED301', 'AED302', 'AED306A', 'AED306B', 'AED323', 'AED390', 'ANS001', 'ANS002', 'ANS021', 'ANS041', 'ARE015', 'ARE100A', 'ARE100B', 'ARE120', 'ARE130', 'ARE135', 'ARE138', 'ARE140', 'ARE150', 'ARE175', 'ARE176', 'BIS002A', 'BIS002B', 'CHE002A', 'CHE002B', 'ECN001A', 'ECN001B', 'EDU110', 'EDU115', 'EDU142', 'ENH001', 'ENH006', 'ENH102', 'ENH105', 'ENH120', 'ENH125', 'ENH133', 'ENH160', 'ESP010', 'ESP100', 'ESP101', 'ESP110', 'ESP123', 'ESP151', 'ESP161', 'ESP170', 'ETX010', 'EVE101', 'EVE115', 'FST109', 'GEL001', 'GEL020', 'HIS017A', 'HYD010', 'HYD047', 'MAT016A', 'MAT016B', 'MAT017A', 'MAT017B', 'MAT021A', 'MAT021B', 'NPB101', 'NPB121', 'NUT115', 'NUT122', 'NUT123', 'PHY007A', 'PHY007B', 'PLB102', 'PLB105', 'PLB116', 'PLB117', 'PLS001', 'PLS002', 'PLS005', 'PLS015', 'PLS049', 'PLS101', 'PLS105', 'PLS150', 'POL001', 'SSC010', 'SSC100', 'SSC102', 'SSC118', 'VEN002', 'VEN003', 'VEN101A', 'VEN101C', 'WFC110', 'WFC111', 'WFC120', 'WFC154'], '/Catalog/are': ['ARE001', 'ARE001S', 'ARE015', 'ARE018', 'ARE098', 'ARE099', 'ARE100A', 'ARE100B', 'ARE106', 'ARE107', 'ARE112', 'ARE113', 'ARE115A', 'ARE115B', 'ARE118', 'ARE119', 'ARE120', 'ARE120S', 'ARE121', 'ARE130', 'ARE132', 'ARE133', 'ARE135', 'ARE136', 'ARE138', 'ARE139', 'ARE140', 'ARE142', 'ARE143', 'ARE144', 'ARE145', 'ARE146', 'ARE147', 'ARE147M', 'ARE150', 'ARE155', 'ARE156', 'ARE157', 'ARE165', 'ARE166', 'ARE171', 'ARE171A', 'ARE171B', 'ARE172', 'ARE173', 'ARE175', 'ARE176', 'ARE190', 'ARE192', 'ARE197T', 'ARE198', 'ARE199', 'ARE200A', 'ARE200B', 'ARE200C', 'ARE202A', 'ARE202B', 'ARE202C', ...

# %%
def main_catalog1():
    #with open('UCD_major.ipynb','w+') as major:
     #   major.readlines()
    f1 = open("UCD_Catalog1.csv", "w+")
    with open("UCD_Catalog1.csv", "w") as toWrite:
        fieldnames = ['MajorID','MajorName']
        writer = csv.DictWriter(toWrite, fieldnames = fieldnames)
        writer.writeheader()
        for x,y in third_final_dict.items():
            writer.writerow({'MajorID' : x, 'MajorName':y})
    f1.close()
main_catalog1()

UCD = pd.read_csv('UCD_Catalog1.csv', header=0)
UCD.columns = ['MajorID','MajorName']
print(UCD.iloc[200])
UCD = UCD.set_index(['MajorID'])
print(UCD)
# Out:
# MajorID      /Catalog/sta
# MajorName      Statistics
# Name: 200, dtype: object
#                                                                                           MajorName
# MajorID
# /Catalog/eae                                       Aerospace Science &amp; Engineering; Engineering
# /Catalog/aas                                                 African American &amp; African Studies
# /Catalog/aging-adult-development                  Aging &amp; Adult Development Minor; Human Eco...
# /Catalog/aed                                             Agricultural &amp; Environmental Education
# /Catalog/are                                                  Agricultural &amp; Resource Economics
# /Catalog/agricultural-pest-management             Agricultural Pest Management Minor; Entomology...
# /Catalog/agricultural-systems-environment         Agricultural Systems &amp; Environment Minor; ...
# /Catalog/ams                                                                       American Studies
# /Catalog/abi                                                                         Animal Biology
# /Catalog/ang                                                                        Animal Genetics
# /Catalog/ans                                                                         Animal Science
# /Catalog/animal-science-management                                  Animal Science &amp; Management
# /Catalog/ant                                                                          Anthropology
# /Catalog/abt                                                  Applied Biological Systems Technology
# /Catalog/applied-computing-information-systems    Applied Computing &amp; Information Systems Mi...
# /Catalog/applied-mathematics                                       Applied Mathematics; Mathematics
# /Catalog/applied-physics                                                   Applied Physics; Physics
# /Catalog/ead                                               Applied Science Engineering; Engineering
# /Catalog/arab-studies-minor                       Arab Studies Minor; Middle East/South Asia Stu...
# /Catalog/arabic-minor                                                        Arabic Minor; Classics
# /Catalog/ahi                                                                            Art History
# /Catalog/art                                                                             Art Studio
# /Catalog/asa                                                                 Asian American Studies
# /Catalog/atm                                                                    Atmospheric Science
# /Catalog/avs                                                                         Avian Sciences
# /Catalog/biochemical-engineering                               Biochemical Engineering; Engineering
# /Catalog/biochemistry-molecular-biology           Biochemistry &amp; Molecular Biology; Molecula...
# /Catalog/biological-agricultural-engineering      Biological &amp; Agricultural Engineering; Agr...
# /Catalog/bis                                                                    Biological Sciences
# /Catalog/ebs                                      Biological Systems Engineering; Agricultural &...
# ...                                                                                             ...
# /Catalog/quantitative-biology-bioinformatics      Quantitative Biology &amp; Bioinformatics Mino...
# /Catalog/rst                                                                      Religious Studies
# /Catalog/rus                                                                                Russian
# /Catalog/sas                                      Science &amp; Society Minor; Science &amp; Soc...
# /Catalog/sts                                                       Science &amp; Technology Studies
# /Catalog/science-teaching-credential                                    Science Teaching Credential
# /Catalog/sexuality-studies                        Sexuality Studies Minor; Gender, Sexuality &am...
# /Catalog/social-ethnic-relations                                Social &amp; Ethnic Relations Minor
# /Catalog/social-sciences                                                            Social Sciences
# /Catalog/social-theory-comparative-history                  Social Theory &amp; Comparative History
# /Catalog/soc                                                                              Sociology
# /Catalog/ssc                                      Soil Science Minor; Land, Air &amp; Water Reso...
# /Catalog/spa                                                                                Spanish
# /Catalog/sta                                                                             Statistics
# /Catalog/sustainability-in-the-built-environment  Sustainability in the Built Environment Minor;...
# /Catalog/saf                                             Sustainable Agriculture &amp; Food Systems
# /Catalog/sustainable-environmental-design                          Sustainable Environmental Design
# /Catalog/teaching-credential                      Teaching Credential/M.A. Program; Education, S...
# /Catalog/tcs                                                                 Technocultural Studies
# /Catalog/txc                                                                Textiles &amp; Clothing
# /Catalog/dra                                                                    Theatre &amp; Dance
# /Catalog/eap                                                                  UC Davis Study Abroad
# /Catalog/washington                                                            UC Washington Center
# /Catalog/hnr                                                              University Honors Program
# /Catalog/uwp                                                             University Writing Program
# /Catalog/veterinary-medicine                                         Veterinary Medicine, School of
# /Catalog/ven                                                              Viticulture &amp; Enology
# /Catalog/war-peace-studies                         War-Peace Studies Minor; International Relations
# /Catalog/watershed-science                        Watershed Science Minor; Land, Air &amp; Water...
# /Catalog/wfc                                             Wildlife, Fish, &amp; Conservation Biology
#
# [217 rows x 1 columns]

# %%
def main_course():
    file = open("UCD_Catalog_course.csv", "w+")
    with open("UCD_Catalog_course.csv", "w") as toWrite:
        fieldnames = ['MajorID','MajorCourse']
        writer = csv.DictWriter(toWrite, fieldnames = fieldnames)
        writer.writeheader()
        for x,y in first_final_course_dict.items():
            writer.writerow({'MajorID' : x, 'MajorCourse':y})
    file.close()    
main_course()

UCD_course = pd.read_csv('UCD_Catalog_course.csv', header=0)
UCD_course.columns = ['MajorID','MajorCourse']
print(UCD_course.iloc[216])
UCD_course = UCD_course.set_index(['MajorID'])
print(UCD_course.head(10))
# Out:
# MajorID                                             /Catalog/wfc
# MajorCourse    ['ABI102', 'ABI103', 'ANS103', 'ANS104', 'ANS1...
# Name: 216, dtype: object
#                                                                                  MajorCourse
# MajorID
# /Catalog/eae                               ['CHE002A', 'CHE002B', 'CMN001', 'CMN003', 'CO...
# /Catalog/aas                               ['AAS010', 'AAS012', 'AAS015', 'AAS016', 'AAS0...
# /Catalog/aging-adult-development           ['EXB117', 'HDE100C', 'HDE110', 'HDE117', 'HDE...
# /Catalog/aed                               ['ABI102', 'ABT016', 'ABT049', 'ABT052', 'ABT1...
# /Catalog/are                               ['ARE001', 'ARE001S', 'ARE015', 'ARE018', 'ARE...
# /Catalog/agricultural-pest-management      ['ENT100', 'ENT100L', 'ENT123', 'NEM100', 'PLB...
# /Catalog/agricultural-systems-environment  ['ENT110', 'ESP123', 'ESP172', 'PLS002', 'PLS1...
# /Catalog/ams                               ['AAS010', 'AMS001A', 'AMS001B', 'AMS001C', 'A...
# /Catalog/abi                               ['ABI050A', 'ABI050B', 'ABI050C', 'ABI092', 'A...
# /Catalog/ang                               ['ANG101', 'ANG105', 'ANG107', 'ANG111', 'ANG1...

# %%
UCD_course_merge = pd.merge(UCD,UCD_course, on='MajorID')
#print(UCD_course_merge)
UCD_course_merge = UCD_course_merge.reset_index(drop = True)
UCD_course_merge = UCD_course_merge.set_index('MajorName')
print(UCD_course_merge)
# Out:
#                                                                                           MajorCourse
# MajorName
# Aerospace Science &amp; Engineering; Engineering    ['CHE002A', 'CHE002B', 'CMN001', 'CMN003', 'CO...
# African American &amp; African Studies              ['AAS010', 'AAS012', 'AAS015', 'AAS016', 'AAS0...
# Aging &amp; Adult Development Minor; Human Ecology  ['EXB117', 'HDE100C', 'HDE110', 'HDE117', 'HDE...
# Agricultural &amp; Environmental Education          ['ABI102', 'ABT016', 'ABT049', 'ABT052', 'ABT1...
# Agricultural &amp; Resource Economics               ['ARE001', 'ARE001S', 'ARE015', 'ARE018', 'ARE...
# Agricultural Pest Management Minor; Entomology ...  ['ENT100', 'ENT100L', 'ENT123', 'NEM100', 'PLB...
# Agricultural Systems &amp; Environment Minor; P...  ['ENT110', 'ESP123', 'ESP172', 'PLS002', 'PLS1...
# American Studies                                    ['AAS010', 'AMS001A', 'AMS001B', 'AMS001C', 'A...
# Animal Biology                                      ['ABI050A', 'ABI050B', 'ABI050C', 'ABI092', 'A...
# Animal Genetics                                     ['ANG101', 'ANG105', 'ANG107', 'ANG111', 'ANG1...
# Animal Science                                      ['ABI102', 'ABI103', 'ABT161', 'ANG107', 'ANG1...
# Animal Science &amp; Management                     ['ABI102', 'ABI103', 'ANG101', 'ANG105', 'ANG1...
# Anthropology                                        ['ANT001', 'ANT001Y', 'ANT002', 'ANT003', 'ANT...
# Applied Biological Systems Technology               ['ABT015', 'ABT016', 'ABT017', 'ABT049', 'ABT0...
# Applied Computing &amp; Information Systems Min...  ['ABT182', 'ANS128', 'ARE106', 'ARE112', 'ARE1...
# Applied Mathematics; Mathematics                    ['BIS002A', 'BIS002B', 'CHE002A', 'CHE002B', '...
# Applied Physics; Physics                            ['ATM120', 'ATM121A', 'ATM121B', 'ATM128', 'CH...
# Applied Science Engineering; Engineering            ['BPT201', 'EAD230', 'EAD289A', 'EAD289B', 'EA...
# Arab Studies Minor; Middle East/South Asia Studies  ['AHI155', 'ANT142', 'ARB001', 'ARB001A', 'ARB...
# Arabic Minor; Classics                              ['AHI155', 'ANT142', 'ARB001', 'ARB001A', 'ARB...
# Art History                                         ['AHI001A', 'AHI001B', 'AHI001C', 'AHI001D', '...
# Art Studio                                          ['AHI001A', 'AHI001B', 'AHI001C', 'AHI001D', '...
# Asian American Studies                              ['AAS101', 'AHI005', 'AHI100', 'AMS100', 'ANT0...
# Atmospheric Science                                 ['ATM005', 'ATM006', 'ATM010', 'ATM060', 'ATM0...
# Avian Sciences                                      ['ANS143', 'ARE130', 'AVS011', 'AVS013', 'AVS0...
# Biochemical Engineering; Engineering                ['BIM102', 'BIM107', 'BIM109', 'BIM117', 'BIM1...
# Biochemistry &amp; Molecular Biology; Molecular...  ['BIS002A', 'BIS002B', 'BIS002C', 'BIS101', 'B...
# Biological &amp; Agricultural Engineering; Agri...                                                 []
# Biological Sciences                                 ['ANG105', 'ANG107', 'ANS104', 'ANS119', 'ANS1...
# Biological Systems Engineering; Agricultural &a...  ['ABT161', 'ANS118', 'ANS143', 'ANS144', 'ANS1...
# ...                                                                                               ...
# Quantitative Biology &amp; Bioinformatics Minor...  ['BIM102', 'BIM105', 'BIM117', 'BIM140', 'BIM1...
# Religious Studies                                   ['RST001', 'RST001A', 'RST001B', 'RST001C', 'R...
# Russian                                             ['RUS001', 'RUS001A', 'RUS002', 'RUS003', 'RUS...
# Science &amp; Society Minor; Science &amp; Society  ['AED172', 'ANT120', 'ARE120', 'ARE147', 'ARE1...
# Science &amp; Technology Studies                    ['AMS001A', 'AMS001E', 'AMS005', 'AMS101G', 'A...
# Science Teaching Credential                                                                        []
# Sexuality Studies Minor; Gender, Sexuality &amp...  ['ASA112', 'CHI160', 'ENL166', 'ENL186', 'HDE0...
# Social &amp; Ethnic Relations Minor                 ['AAS100', 'AAS123', 'AAS133', 'AAS145A', 'ANT...
# Social Sciences                                                                                    []
# Social Theory &amp; Comparative History                      ['STH250', 'STH290', 'STH295', 'STH296']
# Sociology                                           ['AAS010', 'AAS015', 'AAS100', 'AAS107A', 'AAS...
# Soil Science Minor; Land, Air &amp; Water Resou...  ['HYD124', 'HYD134', 'PLS158', 'SSC010', 'SSC0...
# Spanish                                             ['AAS107A', 'AAS180', 'AHI151', 'ANT144', 'CHI...
# Statistics                                          ['ECS010', 'ECS030', 'ECS032A', 'ECS036A', 'EC...
# Sustainability in the Built Environment Minor; ...  ['ANT101', 'ANT104N', 'ARE175', 'ARE176', 'ATM...
# Sustainable Agriculture &amp; Food Systems          ['ABT049', 'ABT052', 'ABT101', 'ABT142', 'AMS1...
# Sustainable Environmental Design                    ['BIS002B', 'ESP171', 'LDA001', 'LDA002', 'LDA...
# Teaching Credential/M.A. Program; Education, Sc...                                                 []
# Technocultural Studies                              ['AMS001A', 'AMS005', 'TCS001', 'TCS005', 'TCS...
# Textiles &amp; Clothing                             ['AHI001A', 'AHI001B', 'AHI001C', 'AHI001D', '...
# Theatre &amp; Dance                                 ['DRA001', 'DRA001S', 'DRA002', 'DRA005', 'DRA...
# UC Davis Study Abroad                                      ['EAP090X', 'EAP180', 'EAP190X', 'EAP192']
# UC Washington Center                                                   ['WAS187', 'WAS192', 'WAS193']
# University Honors Program                           ['HNR090X', 'HNR092', 'HNR094', 'HNR098', 'HNR...
# University Writing Program                          ['UWP001', 'UWP001A', 'UWP001V', 'UWP001Y', 'U...
# Veterinary Medicine, School of                      ['APC092', 'APC099', 'APC100', 'APC192', 'APC1...
# Viticulture &amp; Enology                           ['ABT150', 'ARE100A', 'ARE112', 'ARE113', 'ARE...
# War-Peace Studies Minor; International Relations    ['ANT126B', 'ANT142', 'ANT143A', 'ANT144', 'CO...
# Watershed Science Minor; Land, Air &amp; Water ...  ['ESM100', 'ESM121', 'ESM144', 'ESP151', 'ESP1...
# Wildlife, Fish, &amp; Conservation Biology          ['ABI102', 'ABI103', 'ANS103', 'ANS104', 'ANS1...
#
# [217 rows x 1 columns]

# %%
UCD_course_merge.to_csv('UCD_Catalog_final.csv')
#UCD_course_merge.to_excel('UCD_Catalog_final.xls')
